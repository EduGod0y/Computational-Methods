# %% [markdown]
# <a href="https://colab.research.google.com/github/EduGod0y/Computational-Methods/blob/main/Regress%C3%A3o_linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd

# %%
x = pd.read_csv('dados3.csv')
y = x['y']
x = x[['x1','x2','x3','x4','x5','x6','x7','x8']]

# %%
pd.plotting.scatter_matrix(x)
plt.show()

# %%
# Model initialization
regression_model = LinearRegression()
# Fit the data(train the model)
regression_model.fit(x, y)
# Predict
y_predicted = regression_model.predict(x)

# %%
# model evaluation
rmse = mean_squared_error(y, y_predicted)
r2 = r2_score(y, y_predicted)

# printing values
print('Slope:' ,regression_model.coef_)
print('Intercept:', regression_model.intercept_)
print('Root mean squared error: ', rmse)
print('R2 score: ', r2)

# plotting values

# data points
# plt.scatter(x, y, s=10)
# plt.xlabel('x')
# plt.ylabel('y')

# predicted values
plt.scatter(y, y_predicted, color='r')
plt.plot([i for i in range(5)],[i for i in range(5)],color='k')
plt.show()
# Out:
# Slope: [-1.05382688  0.01230835 -0.06726242 -0.06365887 -0.12634602 -0.13745951
#   1.38155173  1.49295817]
# Intercept: 1.1922138422177735
# Root mean squared error:  0.06233941977251057
# R2 score:  0.8833707294801803

# %% [markdown]
# #**Função Preditora**
# $$y_p = 1.192\; -1.053X_1 \;+ 0.012X_2 \; - 0.067X_3 \;- 0.063X_4 \; -0.126X_5 \;-0.137X_6 \; + 1.381X_7 \;+1.492X_8\; \pm0.062 $$

# %%
x = pd.read_csv('dados3.csv')
y = x['y']
x = x[['x1','x3','x5','x6','x7','x8']]
#Tirando x4 que tem correlação =1 com x1, e x2 que não prediz y

# %%
# Model initialization
regression_model = LinearRegression()
# Fit the data(train the model)
regression_model.fit(x, y)
# Predict
y_predicted = regression_model.predict(x)

# %%
# model evaluation
rmse = mean_squared_error(y, y_predicted)
r2 = r2_score(y, y_predicted)

# printing values
print('Slope:' ,regression_model.coef_)
print('Intercept:', regression_model.intercept_)
print('Root mean squared error: ', rmse)
print('R2 score: ', r2)

# plotting values

# data points
# plt.scatter(x, y, s=10)
# plt.xlabel('x')
# plt.ylabel('y')

# predicted values
plt.scatter(y, y_predicted, color='r')
plt.plot([i for i in range(5)],[i for i in range(5)],color='k')
plt.show()
# Out:
# Slope: [-1.12042163 -0.06799595 -0.12595239 -0.13493983  1.38051059  1.49431934]
# Intercept: 1.1969654615621912
# Root mean squared error:  0.06235225537741726
# R2 score:  0.8833467156660895

# %%
#R2 sem x4,x2 < R2 com x4,x2
